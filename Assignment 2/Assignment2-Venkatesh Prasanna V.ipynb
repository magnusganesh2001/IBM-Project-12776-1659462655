# %% [markdown]
# # 1. Download the dataset: Dataset

# %% [markdown]
# Dataset Sucessfully download and uploaded in colab.

# %% [markdown]
# ## 2. LOADING DATASET

# %%
import numpy as np
import pandas as pd

# %%
ds=pd.read_csv("/content/Churn_Modelling.csv")
ds.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %% [markdown]
# ## 3. Perform Below Visualizations.
# ● Univariate Analysis
# ● Bi - Variate Analysis
# ● Multi - Variate Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ● Univariate Analysis

# %%
ds.hist(column='Age',grid=False,edgecolor='black')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff290fcc4d0>]],
#       dtype=object)

# %% [markdown]
# ● Bi - Variate Analysis

# %%
sns.countplot(x='Gender',data=ds)

# %% [markdown]
# ● Multi - Variate Analysis

# %%
sns.countplot(x="Tenure",data=ds)

# %% [markdown]
# ## 4. Perform descriptive statistics on the dataset.

# %%
ds.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %% [markdown]
# ## 5. Handle the Missing values.

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# ## 6. Find the outliers and replace the outliers

# %%
sns.boxplot(ds['NumOfProducts'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Values above 3 are outliers
outliers=np.where(ds['NumOfProducts']>3)
outliers
# Out:
# (array([   7,   70, 1254, 1469, 1488, 1701, 1876, 2124, 2196, 2285, 2462,
#         2499, 2509, 2541, 2614, 2617, 2872, 3152, 3365, 3841, 4013, 4014,
#         4166, 4260, 4403, 4511, 4516, 4606, 4654, 4748, 4822, 5010, 5137,
#         5235, 5386, 5700, 5904, 6150, 6172, 6279, 6750, 6875, 7257, 7457,
#         7567, 7698, 7724, 7729, 8041, 8590, 8683, 8850, 8923, 9215, 9255,
#         9323, 9370, 9411, 9540, 9565]),)

# %%
for i in outliers:
  ds['NumOfProducts'][i]=3 #replacing with previous value
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
sns.boxenplot(ds['NumOfProducts'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## 7. Check for Categorical columns and perform encoding.

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
ds.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %% [markdown]
# ## 8. Split the data into dependent and independent variables.

# %%
x = ds.iloc[:, 3:13]
y = ds.iloc[:, 13]

# %% [markdown]
# ## 9. Scale the independent variables

# %%
x=x.drop(['Geography','Gender'],axis=1)

# %%
x
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary
# 0                  1        101348.88
# 1                  1        112542.58
# 2                  0        113931.57
# 3                  0         93826.63
# 4                  1         79084.10
# ...              ...              ...
# 9995               0         96270.64
# 9996               1        101699.77
# 9997               1         42085.58
# 9998               0         92888.52
# 9999               0         38190.78
#
# [10000 rows x 8 columns]

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %% [markdown]
# ## 10. Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
xtrain.shape,xtest.shape
# Out:
# ((7000, 8), (3000, 8))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
xtrain=sc.fit_transform(xtrain)
xtest=sc.fit_transform(xtest)

# %%
classifier=Sequential()
classifier.add(Dense(8,activation='relu'))
classifier.add(Dense(16,activation='relu'))
classifier.add(Dense(24,activation='relu'))
classifier.add(Dense(8,activation='relu'))
classifier.add(Dense(1,activation='linear'))

# %%
classifier.compile(optimizer = 'adam', loss = 'mse', metrics = ['accuracy'])

# %%
classifier.fit(xtrain,ytrain,batch_size=10,epochs=100)
# Out:
# Epoch 1/100
# 700/700 [==============================] - 4s 3ms/step - loss: 0.1481 - accuracy: 0.8057
# Epoch 2/100
# 700/700 [==============================] - 2s 2ms/step - loss: 0.1300 - accuracy: 0.8254
# Epoch 3/100
# 700/700 [==============================] - 2s 2ms/step - loss: 0.1217 - accuracy: 0.8413
# Epoch 4/100
# 700/700 [==============================] - 2s 2ms/step - loss: 0.1188 - accuracy: 0.8450
# Epoch 5/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1159 - accuracy: 0.8484
# Epoch 6/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1142 - accuracy: 0.8486
# Epoch 7/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1121 - accuracy: 0.8527
# Epoch 8/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1111 - accuracy: 0.8527
# Epoch 9/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1103 - accuracy: 0.8534
# Epoch 10/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1091 - accuracy: 0.8573
# Epoch 11/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1094 - accuracy: 0.8547
# Epoch 12/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1087 - accuracy: 0.8566
# Epoch 13/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1084 - accuracy: 0.8556
# Epoch 14/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1083 - accuracy: 0.8564
# Epoch 15/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1077 - accuracy: 0.8576
# Epoch 16/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1073 - accuracy: 0.8567
# Epoch 17/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1072 - accuracy: 0.8589
# Epoch 18/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1068 - accuracy: 0.8590
# Epoch 19/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1069 - accuracy: 0.8593
# Epoch 20/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1069 - accuracy: 0.8573
# Epoch 21/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1062 - accuracy: 0.8581
# Epoch 22/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1063 - accuracy: 0.8597
# Epoch 23/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1061 - accuracy: 0.8584
# Epoch 24/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1058 - accuracy: 0.8586
# Epoch 25/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1057 - accuracy: 0.8609
# Epoch 26/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1055 - accuracy: 0.8597
# Epoch 27/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1055 - accuracy: 0.8603
# Epoch 28/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1052 - accuracy: 0.8596
# Epoch 29/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1053 - accuracy: 0.8603
# Epoch 30/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1050 - accuracy: 0.8576
# Epoch 31/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1045 - accuracy: 0.8613
# Epoch 32/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1042 - accuracy: 0.8616
# Epoch 33/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1036 - accuracy: 0.8617
# Epoch 34/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1043 - accuracy: 0.8619
# Epoch 35/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1042 - accuracy: 0.8599
# Epoch 36/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1040 - accuracy: 0.8616
# Epoch 37/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1037 - accuracy: 0.8629
# Epoch 38/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1033 - accuracy: 0.8640
# Epoch 39/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1036 - accuracy: 0.8609
# Epoch 40/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1035 - accuracy: 0.8621
# Epoch 41/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1033 - accuracy: 0.8629
# Epoch 42/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1029 - accuracy: 0.8629
# Epoch 43/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1027 - accuracy: 0.8639
# Epoch 44/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1031 - accuracy: 0.8627
# Epoch 45/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1023 - accuracy: 0.8649
# Epoch 46/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1025 - accuracy: 0.8623
# Epoch 47/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1023 - accuracy: 0.8646
# Epoch 48/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1028 - accuracy: 0.8627
# Epoch 49/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1022 - accuracy: 0.8629
# Epoch 50/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1020 - accuracy: 0.8640
# Epoch 51/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1018 - accuracy: 0.8676
# Epoch 52/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1022 - accuracy: 0.8653
# Epoch 53/100
# 700/700 [==============================] - 2s 2ms/step - loss: 0.1021 - accuracy: 0.8654
# Epoch 54/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1016 - accuracy: 0.8651
# Epoch 55/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1017 - accuracy: 0.8641
# Epoch 56/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1012 - accuracy: 0.8646
# Epoch 57/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1015 - accuracy: 0.8657
# Epoch 58/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1011 - accuracy: 0.8649
# Epoch 59/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1012 - accuracy: 0.8657
# Epoch 60/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1011 - accuracy: 0.8646
# Epoch 61/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1010 - accuracy: 0.8651
# Epoch 62/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1006 - accuracy: 0.8661
# Epoch 63/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1007 - accuracy: 0.8660
# Epoch 64/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1007 - accuracy: 0.8659
# Epoch 65/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1008 - accuracy: 0.8640
# Epoch 66/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1004 - accuracy: 0.8660
# Epoch 67/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1005 - accuracy: 0.8636
# Epoch 68/100
# 700/700 [==============================] - 2s 2ms/step - loss: 0.1003 - accuracy: 0.8663
# Epoch 69/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1000 - accuracy: 0.8667
# Epoch 70/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1004 - accuracy: 0.8657
# Epoch 71/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1003 - accuracy: 0.8641
# Epoch 72/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.1002 - accuracy: 0.8680
# Epoch 73/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.0999 - accuracy: 0.8650
# Epoch 74/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.0998 - accuracy: 0.8674
# Epoch 75/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.0995 - accuracy: 0.8661
# Epoch 76/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.0998 - accuracy: 0.8664
# Epoch 77/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.0996 - accuracy: 0.8676
# Epoch 78/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.0995 - accuracy: 0.8693
# Epoch 79/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.0994 - accuracy: 0.8706
# Epoch 80/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.0992 - accuracy: 0.8674
# Epoch 81/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.0996 - accuracy: 0.8684
# Epoch 82/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.0994 - accuracy: 0.8664
# Epoch 83/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.0991 - accuracy: 0.8654
# Epoch 84/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.0992 - accuracy: 0.8657
# Epoch 85/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.0988 - accuracy: 0.8699
# Epoch 86/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.0990 - accuracy: 0.8693
# Epoch 87/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.0987 - accuracy: 0.8677
# Epoch 88/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.0988 - accuracy: 0.8679
# Epoch 89/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.0983 - accuracy: 0.8693
# Epoch 90/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.0981 - accuracy: 0.8704
# Epoch 91/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.0984 - accuracy: 0.8679
# Epoch 92/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.0986 - accuracy: 0.8693
# Epoch 93/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.0985 - accuracy: 0.8697
# Epoch 94/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.0984 - accuracy: 0.8706
# Epoch 95/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.0985 - accuracy: 0.8686
# Epoch 96/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.0982 - accuracy: 0.8700
# Epoch 97/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.0980 - accuracy: 0.8681
# Epoch 98/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.0980 - accuracy: 0.8691
# Epoch 99/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.0981 - accuracy: 0.8697
# Epoch 100/100
# 700/700 [==============================] - 1s 2ms/step - loss: 0.0983 - accuracy: 0.8681

# %%
ypred=classifier.predict(xtest)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(ytest,ypred)*100
# Out:
# 31.312768522673395
